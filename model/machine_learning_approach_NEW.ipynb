# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
data = pd.read_excel('../game_scraping/scraping_results.xlsx', index_col=0)

# %%
data['Week'].unique()

data['Series'] = 1

# Initialize the series counter
series_counter = 1

# Iterate through the dataframe to update the Series column
for i in range(1, len(data)):
    if data.loc[i, 'Week'] == 1 and data.loc[i-1, 'Week'] != 1:
        series_counter += 1
    data.loc[i, 'Series'] = series_counter

data['revenue_unit'] = data['Price'] * data['Sales']

data['previous_sales'] = data.groupby('Series')['Sales'].shift(1)
data['previous_price'] = data.groupby('Series')['Price'].shift(1)
data['change_price'] = data.groupby('Series')['Price'].diff()
data['remaining_previous'] = data.groupby('Series')['Remaining'].shift(1)
data
# Out:
#       Week  Price  Sales  Remaining  \
# 0        1     60     87       1913
# 1        2     60     74       1839
# 2        3     54    147       1692
# 3        4     54     45       1647
# 4        5     48    160       1487
# ...    ...    ...    ...        ...
# 1495    11     36    100          0
# 1496    12     36      0          0
# 1497    13     36      0          0
# 1498    14     36      0          0
# 1499    15     36      0          0
#
#                                               foresight  Choice  diff  \
# 0     Your revenue: $85,752, Perfect foresight strat...       0  15.8
# 1     Your revenue: $85,752, Perfect foresight strat...       0  15.8
# 2     Your revenue: $85,752, Perfect foresight strat...       1  15.8
# 3     Your revenue: $85,752, Perfect foresight strat...       0  15.8
# 4     Your revenue: $85,752, Perfect foresight strat...       2  15.8
# ...                                                 ...     ...   ...
# 1495  Your revenue: $82,860, Perfect foresight strat...       0  20.0
# 1496  Your revenue: $82,860, Perfect foresight strat...       0  20.0
# 1497  Your revenue: $82,860, Perfect foresight strat...       0  20.0
# 1498  Your revenue: $82,860, Perfect foresight strat...       0  20.0
# 1499  Your revenue: $82,860, Perfect foresight strat...       0  20.0
#
#       revenue  perfect  Series  revenue_unit  previous_sales  previous_price  \
# 0       85752   101892       1          5220             NaN             NaN
# 1       85752   101892       1          4440            87.0            60.0
# 2       85752   101892       1          7938            74.0            60.0
# 3       85752   101892       1          2430           147.0            54.0
# 4       85752   101892       1          7680            45.0            54.0
# ...       ...      ...     ...           ...             ...             ...
# 1495    82860   103596     100          3600           206.0            36.0
# 1496    82860   103596     100             0           100.0            36.0
# 1497    82860   103596     100             0             0.0            36.0
# 1498    82860   103596     100             0             0.0            36.0
# 1499    82860   103596     100             0             0.0            36.0
#
#       change_price  remaining_previous
# 0              NaN                 NaN
# 1              0.0              1913.0
# 2             -6.0              1839.0
# 3              0.0              1692.0
# 4             -6.0              1647.0
# ...            ...                 ...
# 1495           0.0               100.0
# 1496           0.0                 0.0
# 1497           0.0                 0.0
# 1498           0.0                 0.0
# 1499           0.0                 0.0
#
# [1500 rows x 15 columns]

# %%
from sklearn.linear_model import LinearRegression   
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error, r2_score, mean_absolute_percentage_error

linear_model = LinearRegression()
linear_model.fit(data[['Week','Price']], data[['Sales']])
preds = linear_model.predict(data[['Week','Price']])

print('R2 score:',r2_score(data[['Sales']], preds))
print('MAE:',mean_absolute_error(data[['Sales']], preds))
print('MAPE:',mean_absolute_percentage_error(data[['Sales']], preds))   
print(linear_model.coef_)
# Out:
# R2 score: 0.3171610790613203
# MAE: 62.95957184179123
# MAPE: 6.655982285142552e+16
# [[-26.81353903 -12.52288096]]

# %%
### More variables and boosting model


from xgboost import XGBRegressor

#### Train and test split

train = data[data['Series'] <= 80]
test = data[data['Series'] > 80]

model = XGBRegressor(n_estimators=500, learning_rate=0.01, random_state=123, max_depth = 3)
model.fit(train[['Week','Price','previous_sales','previous_price','change_price','remaining_previous']], train['Sales'])
preds = model.predict(test[['Week','Price','previous_sales','previous_price','change_price','remaining_previous']])

print('R2 score:',r2_score(test[['Sales']], preds))
print('MAE:',mean_absolute_error(test[['Sales']], preds))
print('MAPE:',mean_absolute_percentage_error(test[['Sales']], preds))
# Out:
# R2 score: 0.7010067543411818
# MAE: 34.11835731665293
# MAPE: 2929533032948476.5

# %%
test.head()
# Out:
#       Week  Price  Sales  Remaining  \
# 1200     1     60     87       1913
# 1201     2     60     64       1849
# 1202     3     54    141       1708
# 1203     4     54    132       1576
# 1204     5     48    200       1376
#
#                                               foresight  Choice  diff  \
# 1200  Your revenue: $84,354, Perfect foresight strat...       0  17.7
# 1201  Your revenue: $84,354, Perfect foresight strat...       0  17.7
# 1202  Your revenue: $84,354, Perfect foresight strat...       1  17.7
# 1203  Your revenue: $84,354, Perfect foresight strat...       0  17.7
# 1204  Your revenue: $84,354, Perfect foresight strat...       2  17.7
#
#       revenue  perfect  Series  revenue_unit  previous_sales  previous_price  \
# 1200    84354   102558      81          5220             NaN             NaN
# 1201    84354   102558      81          3840            87.0            60.0
# 1202    84354   102558      81          7614            64.0            60.0
# 1203    84354   102558      81          7128           141.0            54.0
# 1204    84354   102558      81          9600           132.0            54.0
#
#       change_price  remaining_previous
# 1200           NaN                 NaN
# 1201           0.0              1913.0
# 1202          -6.0              1849.0
# 1203           0.0              1708.0
# 1204          -6.0              1576.0

# %%
from gurobipy import Model, GRB
import gurobipy as gp


pricing_model = Model('pricing')

### Decision variables 

prices_decision = pricing_model.addVars(data['Week'].unique(), lb=0, ub = 3, vtype=GRB.INTEGER, name='prices')

### Objective function
def obj(decisions):
    ## Decisions is a list of len = 15
    initial_price = 60
    allowed_prices = [60, 54, 48, 36]
    initial_stock = 2000

    prices = []
    stock_evolution = []
    revenue_evolution = []
    sales_evolution = []    
    for week in range(1,16):
        print(decisions)
        decision = decisions[week].getAttr('x')
        if week == 1: 
            tobe_predicted = np.array([[week, initial_price, np.nan, np.nan, np.nan, np.nan]])
            sales_predicted = np.floor(model.predict(tobe_predicted))
            new_remaining = initial_stock - sales_predicted[0]
            stock_evolution.append(new_remaining)
            old_price = initial_price
            prices.append(initial_price)
            revenue = sales_predicted[0] * initial_price
            revenue_evolution.append(revenue)
            sales_evolution.append(sales_predicted[0])
            
        else:
            new_price = allowed_prices[decision]
            
            if new_price <= old_price:
                new_price = new_price
            else:
                new_price = old_price
            tobe_predicted = np.array([[week, new_price, sales_predicted[0], old_price, new_price - old_price, new_remaining]])
            sales_predicted = np.floor(model.predict(tobe_predicted))
            if sales_predicted[0] > new_remaining:
                sales_predicted[0] = new_remaining
            new_remaining = new_remaining - sales_predicted[0]
            revenue = sales_predicted[0] * new_price
            sales_evolution.append(sales_predicted[0])
            revenue_evolution.append(revenue)
            stock_evolution.append(new_remaining)
            old_price = new_price
            prices.append(new_price)

    total_revenue = sum(revenue_evolution)
    return total_revenue

pricing_model.setObjective(obj(prices_decision), GRB.MAXIMIZE)

pricing_model.optimize()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[456], line 10
#       7 ### Decision variables
#       9 prices_decision = pricing_model.addVars(data['Week'].unique(), lb=0, ub = 3, vtype=GRB.INTEGER, name='prices')
# ---> 10 print(prices_decision[1].getAttr(GRB.Attr.X))
#      11 ### Objective function
#      12 def obj(decisions):
#      13     ## Decisions is a list of len = 15
#
# File src/gurobipy/var.pxi:153, in gurobipy.Var.getAttr()
#
# File src/gurobipy/attrutil.pxi:103, in gurobipy._getattr()
#
# AttributeError: Index out of range for attribute 'X'

# %%
def obj(decisions):
    ## Decisions is a list of len = 15
    initial_price = 60
    allowed_prices = [60, 54, 48, 36]
    initial_stock = 2000

    prices = []
    stock_evolution = []
    revenue_evolution = []
    sales_evolution = []    
    for week in range(1,16):
        decision = decisions[week-1]
        if week == 1: 
            tobe_predicted = np.array([[week, initial_price, np.nan, np.nan, np.nan, np.nan]])
            sales_predicted = np.floor(model.predict(tobe_predicted))
            new_remaining = initial_stock - sales_predicted[0]
            stock_evolution.append(new_remaining)
            old_price = initial_price
            prices.append(initial_price)
            revenue = sales_predicted[0] * initial_price
            revenue_evolution.append(revenue)
            sales_evolution.append(sales_predicted[0])
            
        else:
            new_price = allowed_prices[decision]
            
            if new_price <= old_price:
                new_price = new_price
            else:
                new_price = old_price
            tobe_predicted = np.array([[week, new_price, sales_predicted[0], old_price, new_price - old_price, new_remaining]])
            sales_predicted = np.floor(model.predict(tobe_predicted))
            if sales_predicted[0] > new_remaining:
                sales_predicted[0] = new_remaining
            new_remaining = new_remaining - sales_predicted[0]
            revenue = sales_predicted[0] * new_price
            sales_evolution.append(sales_predicted[0])
            revenue_evolution.append(revenue)
            stock_evolution.append(new_remaining)
            old_price = new_price
            prices.append(new_price)

    total_revenue = sum(revenue_evolution)
    return total_revenue,prices

# %%
import optuna

def objective(trial):
    prices = [
        trial.suggest_int('price_1', 0, 3),
        trial.suggest_int('price_2', 0, 3),
        trial.suggest_int('price_3', 0, 3),
        trial.suggest_int('price_4', 0, 3),
        trial.suggest_int('price_5', 0, 3),
        trial.suggest_int('price_6', 0, 3),
        trial.suggest_int('price_7', 0, 3),
        trial.suggest_int('price_8', 0, 3),
        trial.suggest_int('price_9', 0, 3),
        trial.suggest_int('price_10', 0, 3),
        trial.suggest_int('price_11', 0, 3),
        trial.suggest_int('price_12', 0, 3),
        trial.suggest_int('price_13', 0, 3),
        trial.suggest_int('price_14', 0, 3),
        trial.suggest_int('price_15', 0, 3),
    ]
    total_revenue,prices = obj(prices)
              
    return total_revenue

study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=100)
# Out:
# [I 2024-05-20 18:39:01,485] A new study created in memory with name: no-name-bc914d08-0a3c-459e-8203-e5efe2f936fd
# [I 2024-05-20 18:39:01,490] Trial 0 finished with value: 83688.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 2, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 3, 'price_8': 0, 'price_9': 0, 'price_10': 1, 'price_11': 1, 'price_12': 0, 'price_13': 0, 'price_14': 3, 'price_15': 2}. Best is trial 0 with value: 83688.0.
# [I 2024-05-20 18:39:01,494] Trial 1 finished with value: 74112.0 and parameters: {'price_1': 1, 'price_2': 3, 'price_3': 2, 'price_4': 2, 'price_5': 0, 'price_6': 2, 'price_7': 1, 'price_8': 0, 'price_9': 1, 'price_10': 0, 'price_11': 3, 'price_12': 0, 'price_13': 0, 'price_14': 0, 'price_15': 1}. Best is trial 0 with value: 83688.0.
# [I 2024-05-20 18:39:01,499] Trial 2 finished with value: 77700.0 and parameters: {'price_1': 1, 'price_2': 2, 'price_3': 2, 'price_4': 3, 'price_5': 1, 'price_6': 0, 'price_7': 1, 'price_8': 2, 'price_9': 1, 'price_10': 2, 'price_11': 0, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 0}. Best is trial 0 with value: 83688.0.
# [I 2024-05-20 18:39:01,502] Trial 3 finished with value: 95016.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 0, 'price_5': 0, 'price_6': 1, 'price_7': 2, 'price_8': 2, 'price_9': 1, 'price_10': 0, 'price_11': 2, 'price_12': 3, 'price_13': 3, 'price_14': 1, 'price_15': 1}. Best is trial 3 with value: 95016.0.
# [I 2024-05-20 18:39:01,506] Trial 4 finished with value: 85248.0 and parameters: {'price_1': 2, 'price_2': 2, 'price_3': 2, 'price_4': 2, 'price_5': 0, 'price_6': 2, 'price_7': 1, 'price_8': 3, 'price_9': 0, 'price_10': 2, 'price_11': 3, 'price_12': 0, 'price_13': 1, 'price_14': 3, 'price_15': 0}. Best is trial 3 with value: 95016.0.
# [I 2024-05-20 18:39:01,509] Trial 5 finished with value: 92472.0 and parameters: {'price_1': 0, 'price_2': 1, 'price_3': 2, 'price_4': 0, 'price_5': 2, 'price_6': 2, 'price_7': 1, 'price_8': 1, 'price_9': 2, 'price_10': 2, 'price_11': 3, 'price_12': 2, 'price_13': 3, 'price_14': 0, 'price_15': 3}. Best is trial 3 with value: 95016.0.
# [I 2024-05-20 18:39:01,512] Trial 6 finished with value: 81708.0 and parameters: {'price_1': 0, 'price_2': 1, 'price_3': 2, 'price_4': 2, 'price_5': 1, 'price_6': 3, 'price_7': 1, 'price_8': 1, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 0}. Best is trial 3 with value: 95016.0.
# [I 2024-05-20 18:39:01,514] Trial 7 finished with value: 74112.0 and parameters: {'price_1': 2, 'price_2': 3, 'price_3': 3, 'price_4': 3, 'price_5': 1, 'price_6': 3, 'price_7': 2, 'price_8': 1, 'price_9': 0, 'price_10': 2, 'price_11': 1, 'price_12': 3, 'price_13': 2, 'price_14': 2, 'price_15': 2}. Best is trial 3 with value: 95016.0.
# [I 2024-05-20 18:39:01,517] Trial 8 finished with value: 80034.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 2, 'price_5': 3, 'price_6': 0, 'price_7': 1, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 0, 'price_13': 2, 'price_14': 1, 'price_15': 3}. Best is trial 3 with value: 95016.0.
# [I 2024-05-20 18:39:01,520] Trial 9 finished with value: 76128.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 3, 'price_4': 1, 'price_5': 0, 'price_6': 2, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 0, 'price_11': 3, 'price_12': 0, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 3 with value: 95016.0.
# [I 2024-05-20 18:39:01,549] Trial 10 finished with value: 80160.0 and parameters: {'price_1': 2, 'price_2': 0, 'price_3': 0, 'price_4': 0, 'price_5': 3, 'price_6': 1, 'price_7': 3, 'price_8': 3, 'price_9': 3, 'price_10': 1, 'price_11': 2, 'price_12': 3, 'price_13': 3, 'price_14': 2, 'price_15': 1}. Best is trial 3 with value: 95016.0.
# [I 2024-05-20 18:39:01,578] Trial 11 finished with value: 87540.0 and parameters: {'price_1': 0, 'price_2': 1, 'price_3': 1, 'price_4': 0, 'price_5': 2, 'price_6': 1, 'price_7': 2, 'price_8': 2, 'price_9': 3, 'price_10': 3, 'price_11': 2, 'price_12': 2, 'price_13': 3, 'price_14': 1, 'price_15': 3}. Best is trial 3 with value: 95016.0.
# [I 2024-05-20 18:39:01,608] Trial 12 finished with value: 89580.0 and parameters: {'price_1': 1, 'price_2': 0, 'price_3': 0, 'price_4': 0, 'price_5': 2, 'price_6': 1, 'price_7': 0, 'price_8': 2, 'price_9': 1, 'price_10': 3, 'price_11': 2, 'price_12': 2, 'price_13': 3, 'price_14': 0, 'price_15': 2}. Best is trial 3 with value: 95016.0.
# [I 2024-05-20 18:39:01,636] Trial 13 finished with value: 92028.0 and parameters: {'price_1': 0, 'price_2': 2, 'price_3': 1, 'price_4': 1, 'price_5': 2, 'price_6': 2, 'price_7': 2, 'price_8': 1, 'price_9': 2, 'price_10': 1, 'price_11': 3, 'price_12': 3, 'price_13': 2, 'price_14': 1, 'price_15': 3}. Best is trial 3 with value: 95016.0.
# [I 2024-05-20 18:39:01,665] Trial 14 finished with value: 96396.0 and parameters: {'price_1': 2, 'price_2': 1, 'price_3': 1, 'price_4': 0, 'price_5': 2, 'price_6': 1, 'price_7': 2, 'price_8': 2, 'price_9': 1, 'price_10': 0, 'price_11': 2, 'price_12': 2, 'price_13': 3, 'price_14': 2, 'price_15': 2}. Best is trial 14 with value: 96396.0.
# [I 2024-05-20 18:39:01,693] Trial 15 finished with value: 79512.0 and parameters: {'price_1': 3, 'price_2': 2, 'price_3': 0, 'price_4': 0, 'price_5': 3, 'price_6': 1, 'price_7': 3, 'price_8': 2, 'price_9': 1, 'price_10': 0, 'price_11': 2, 'price_12': 3, 'price_13': 3, 'price_14': 2, 'price_15': 1}. Best is trial 14 with value: 96396.0.
# [I 2024-05-20 18:39:01,722] Trial 16 finished with value: 86616.0 and parameters: {'price_1': 2, 'price_2': 0, 'price_3': 1, 'price_4': 1, 'price_5': 0, 'price_6': 1, 'price_7': 2, 'price_8': 3, 'price_9': 1, 'price_10': 0, 'price_11': 0, 'price_12': 2, 'price_13': 2, 'price_14': 2, 'price_15': 2}. Best is trial 14 with value: 96396.0.
# [I 2024-05-20 18:39:01,750] Trial 17 finished with value: 97056.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 0, 'price_5': 1, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 2, 'price_12': 1, 'price_13': 3, 'price_14': 3, 'price_15': 1}. Best is trial 17 with value: 97056.0.
# [I 2024-05-20 18:39:01,777] Trial 18 finished with value: 83244.0 and parameters: {'price_1': 2, 'price_2': 2, 'price_3': 0, 'price_4': 1, 'price_5': 2, 'price_6': 0, 'price_7': 3, 'price_8': 3, 'price_9': 0, 'price_10': 1, 'price_11': 2, 'price_12': 1, 'price_13': 2, 'price_14': 3, 'price_15': 2}. Best is trial 17 with value: 97056.0.
# [I 2024-05-20 18:39:01,806] Trial 19 finished with value: 97176.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 0, 'price_5': 1, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 1, 'price_12': 1, 'price_13': 3, 'price_14': 3, 'price_15': 1}. Best is trial 19 with value: 97176.0.
# [I 2024-05-20 18:39:01,834] Trial 20 finished with value: 84894.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 3, 'price_8': 1, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 1, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 19 with value: 97176.0.
# [I 2024-05-20 18:39:01,863] Trial 21 finished with value: 97176.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 0, 'price_5': 1, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 1, 'price_12': 1, 'price_13': 3, 'price_14': 3, 'price_15': 1}. Best is trial 19 with value: 97176.0.
# [I 2024-05-20 18:39:01,891] Trial 22 finished with value: 97176.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 0, 'price_5': 1, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 1, 'price_12': 1, 'price_13': 3, 'price_14': 3, 'price_15': 1}. Best is trial 19 with value: 97176.0.
# [I 2024-05-20 18:39:01,916] Trial 23 finished with value: 97176.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 0, 'price_5': 1, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 1, 'price_12': 1, 'price_13': 3, 'price_14': 3, 'price_15': 1}. Best is trial 19 with value: 97176.0.
# [I 2024-05-20 18:39:01,943] Trial 24 finished with value: 86616.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 0, 'price_5': 1, 'price_6': 0, 'price_7': 2, 'price_8': 3, 'price_9': 0, 'price_10': 1, 'price_11': 1, 'price_12': 1, 'price_13': 3, 'price_14': 3, 'price_15': 1}. Best is trial 19 with value: 97176.0.
# [I 2024-05-20 18:39:01,969] Trial 25 finished with value: 99180.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 1, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:01,996] Trial 26 finished with value: 84894.0 and parameters: {'price_1': 2, 'price_2': 0, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 3, 'price_8': 1, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 1, 'price_13': 2, 'price_14': 2, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,023] Trial 27 finished with value: 99180.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 1, 'price_5': 0, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 2, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,049] Trial 28 finished with value: 85476.0 and parameters: {'price_1': 2, 'price_2': 0, 'price_3': 2, 'price_4': 1, 'price_5': 0, 'price_6': 1, 'price_7': 1, 'price_8': 3, 'price_9': 1, 'price_10': 2, 'price_11': 0, 'price_12': 2, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,077] Trial 29 finished with value: 76128.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 3, 'price_4': 2, 'price_5': 0, 'price_6': 0, 'price_7': 3, 'price_8': 2, 'price_9': 0, 'price_10': 0, 'price_11': 0, 'price_12': 2, 'price_13': 1, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,106] Trial 30 finished with value: 84516.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 0, 'price_6': 0, 'price_7': 3, 'price_8': 1, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 0, 'price_13': 0, 'price_14': 2, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,134] Trial 31 finished with value: 99180.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 1, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,161] Trial 32 finished with value: 99180.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 1, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,189] Trial 33 finished with value: 99180.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 1, 'price_5': 0, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 2, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,217] Trial 34 finished with value: 97752.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 2, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 1, 'price_10': 1, 'price_11': 0, 'price_12': 0, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,246] Trial 35 finished with value: 74112.0 and parameters: {'price_1': 1, 'price_2': 3, 'price_3': 1, 'price_4': 1, 'price_5': 0, 'price_6': 0, 'price_7': 1, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 1, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,274] Trial 36 finished with value: 85692.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 2, 'price_4': 2, 'price_5': 1, 'price_6': 1, 'price_7': 1, 'price_8': 3, 'price_9': 1, 'price_10': 0, 'price_11': 0, 'price_12': 2, 'price_13': 1, 'price_14': 2, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,302] Trial 37 finished with value: 98148.0 and parameters: {'price_1': 2, 'price_2': 0, 'price_3': 1, 'price_4': 1, 'price_5': 2, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 2, 'price_11': 0, 'price_12': 1, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,329] Trial 38 finished with value: 97524.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 2, 'price_4': 2, 'price_5': 0, 'price_6': 1, 'price_7': 2, 'price_8': 1, 'price_9': 1, 'price_10': 2, 'price_11': 0, 'price_12': 0, 'price_13': 0, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,358] Trial 39 finished with value: 78252.0 and parameters: {'price_1': 2, 'price_2': 0, 'price_3': 1, 'price_4': 3, 'price_5': 1, 'price_6': 3, 'price_7': 1, 'price_8': 2, 'price_9': 0, 'price_10': 2, 'price_11': 0, 'price_12': 1, 'price_13': 1, 'price_14': 2, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,385] Trial 40 finished with value: 85476.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 2, 'price_4': 2, 'price_5': 1, 'price_6': 0, 'price_7': 2, 'price_8': 3, 'price_9': 0, 'price_10': 0, 'price_11': 0, 'price_12': 2, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,414] Trial 41 finished with value: 99180.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 1, 'price_5': 0, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 2, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,442] Trial 42 finished with value: 99180.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 1, 'price_5': 0, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 2, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,470] Trial 43 finished with value: 99180.0 and parameters: {'price_1': 3, 'price_2': 0, 'price_3': 1, 'price_4': 1, 'price_5': 0, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 2, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 25 with value: 99180.0.
# [I 2024-05-20 18:39:02,498] Trial 44 finished with value: 99240.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 0, 'price_6': 0, 'price_7': 2, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 0, 'price_12': 1, 'price_13': 2, 'price_14': 3, 'price_15': 0}. Best is trial 44 with value: 99240.0.
# [I 2024-05-20 18:39:02,527] Trial 45 finished with value: 99834.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 1, 'price_8': 2, 'price_9': 0, 'price_10': 1, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 3, 'price_15': 0}. Best is trial 45 with value: 99834.0.
# [I 2024-05-20 18:39:02,556] Trial 46 finished with value: 97590.0 and parameters: {'price_1': 2, 'price_2': 1, 'price_3': 1, 'price_4': 2, 'price_5': 0, 'price_6': 1, 'price_7': 1, 'price_8': 1, 'price_9': 1, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 2, 'price_15': 0}. Best is trial 45 with value: 99834.0.
# [I 2024-05-20 18:39:02,585] Trial 47 finished with value: 89178.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 2, 'price_9': 3, 'price_10': 1, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 3, 'price_15': 0}. Best is trial 45 with value: 99834.0.
# [I 2024-05-20 18:39:02,615] Trial 48 finished with value: 96000.0 and parameters: {'price_1': 3, 'price_2': 2, 'price_3': 1, 'price_4': 1, 'price_5': 2, 'price_6': 1, 'price_7': 1, 'price_8': 2, 'price_9': 0, 'price_10': 0, 'price_11': 1, 'price_12': 0, 'price_13': 1, 'price_14': 2, 'price_15': 0}. Best is trial 45 with value: 99834.0.
# [I 2024-05-20 18:39:02,643] Trial 49 finished with value: 97524.0 and parameters: {'price_1': 1, 'price_2': 1, 'price_3': 2, 'price_4': 2, 'price_5': 0, 'price_6': 2, 'price_7': 1, 'price_8': 1, 'price_9': 1, 'price_10': 1, 'price_11': 0, 'price_12': 1, 'price_13': 0, 'price_14': 3, 'price_15': 0}. Best is trial 45 with value: 99834.0.
# [I 2024-05-20 18:39:02,673] Trial 50 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:02,702] Trial 51 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:02,733] Trial 52 finished with value: 91644.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 3, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:02,763] Trial 53 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:02,793] Trial 54 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:02,822] Trial 55 finished with value: 82284.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 3, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:02,852] Trial 56 finished with value: 98772.0 and parameters: {'price_1': 2, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 2, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 0, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:02,881] Trial 57 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:02,912] Trial 58 finished with value: 99264.0 and parameters: {'price_1': 0, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 2, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:02,941] Trial 59 finished with value: 89724.0 and parameters: {'price_1': 3, 'price_2': 2, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 3, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 2}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:02,971] Trial 60 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,001] Trial 61 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,031] Trial 62 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,061] Trial 63 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,090] Trial 64 finished with value: 89232.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 3, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,119] Trial 65 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,150] Trial 66 finished with value: 96000.0 and parameters: {'price_1': 3, 'price_2': 2, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 2, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 2, 'price_12': 1, 'price_13': 0, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,179] Trial 67 finished with value: 91644.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 0, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 3, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,211] Trial 68 finished with value: 89232.0 and parameters: {'price_1': 2, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 3, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,242] Trial 69 finished with value: 98772.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 2, 'price_6': 2, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,272] Trial 70 finished with value: 96000.0 and parameters: {'price_1': 3, 'price_2': 2, 'price_3': 0, 'price_4': 2, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 0, 'price_13': 0, 'price_14': 0, 'price_15': 2}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,303] Trial 71 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,334] Trial 72 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,365] Trial 73 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,395] Trial 74 finished with value: 76344.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 3, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,425] Trial 75 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 2, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,456] Trial 76 finished with value: 91644.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 3, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,486] Trial 77 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,517] Trial 78 finished with value: 100968.0 and parameters: {'price_1': 1, 'price_2': 1, 'price_3': 0, 'price_4': 0, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,548] Trial 79 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 2, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,578] Trial 80 finished with value: 80124.0 and parameters: {'price_1': 2, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 3, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 3, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 2}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,609] Trial 81 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,640] Trial 82 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,670] Trial 83 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,701] Trial 84 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,733] Trial 85 finished with value: 99264.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 2, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,763] Trial 86 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,795] Trial 87 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,827] Trial 88 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 1, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,858] Trial 89 finished with value: 74112.0 and parameters: {'price_1': 3, 'price_2': 3, 'price_3': 0, 'price_4': 3, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 3, 'price_12': 1, 'price_13': 0, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,890] Trial 90 finished with value: 98772.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 2, 'price_6': 2, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 0, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,921] Trial 91 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,953] Trial 92 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:03,985] Trial 93 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:04,016] Trial 94 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:04,047] Trial 95 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:04,079] Trial 96 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 1, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 0, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:04,109] Trial 97 finished with value: 100968.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 2, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:04,140] Trial 98 finished with value: 87780.0 and parameters: {'price_1': 3, 'price_2': 1, 'price_3': 2, 'price_4': 1, 'price_5': 1, 'price_6': 0, 'price_7': 0, 'price_8': 0, 'price_9': 3, 'price_10': 2, 'price_11': 1, 'price_12': 3, 'price_13': 1, 'price_14': 0, 'price_15': 3}. Best is trial 50 with value: 100968.0.
# [I 2024-05-20 18:39:04,172] Trial 99 finished with value: 89724.0 and parameters: {'price_1': 3, 'price_2': 2, 'price_3': 0, 'price_4': 1, 'price_5': 1, 'price_6': 1, 'price_7': 0, 'price_8': 0, 'price_9': 2, 'price_10': 3, 'price_11': 1, 'price_12': 1, 'price_13': 1, 'price_14': 1, 'price_15': 1}. Best is trial 50 with value: 100968.0.

# %%
obj(list(study.best_params.values()))[1]
# Out:
# [60, 54, 54, 54, 54, 54, 54, 54, 48, 48, 48, 48, 48, 48, 48]
